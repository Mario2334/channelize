# %%
import requests
url= '''https://api.etherscan.io/api?module=logs&action=getLogs&address=0x7002049FDCa829ED7082EFA03860b078aD4B5Efe&page=1&offset=1000&apikey=7ZJG7KUUBV1TXSSTYP2C4B344ZP6S736IB'''

# %%
response = requests.get(url)
response.json()
# Out:
# {'status': '1',
#  'message': 'OK',
#  'result': [{'address': '0x7002049fdca829ed7082efa03860b078ad4b5efe',
#    'topics': ['0xd0d9486a2c673e2a4b57fc82e4c8a556b3e2b82dd5db07e2c04a920ca0f469b6'],
#    'data': '',
#    'blockNumber': '0xb5ef6f',
#    'blockHash': '0x0e848687b7522ac2972ba29941a901ac5ad8e794ca3d88e7346510e3a14842aa',
#    'timeStamp': '0x6036f9f8',
#    'gasPrice': '0x205d0bae00',
#    'gasUsed': '0x593ac4',
#    'logIndex': '0xc4',
#    'transactionHash': '0x6a7df34da704a51b34055ff2687dfbb912a3ce0ad80fc6c607480fed173b801c',
#    'transactionIndex': '0x8e'},
#   {'address': '0x7002049fdca829ed7082efa03860b078ad4b5efe',
# ...
